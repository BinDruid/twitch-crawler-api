# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from apps.chat.models import Chat, Emote
from django.db.models import Count, F, Sum
from django.db.models.functions import Extract

# %%
queryset= Chat.objects.values("emojis__emoji").annotate(count=Sum("emojis__count")).order_by("-count")
list(queryset)
# Out:
# [{'emojis__emoji': None, 'count': None},
#  {'emojis__emoji': '🐍', 'count': 846},
#  {'emojis__emoji': '⭐', 'count': 262},
#  {'emojis__emoji': '👉', 'count': 179},
#  {'emojis__emoji': '⚠️', 'count': 165},
#  {'emojis__emoji': '⛏', 'count': 96},
#  {'emojis__emoji': '🦟', 'count': 88},
#  {'emojis__emoji': '🦌', 'count': 73},
#  {'emojis__emoji': '🤢', 'count': 57},
#  {'emojis__emoji': '💢', 'count': 43},
#  {'emojis__emoji': '⛵', 'count': 39},
#  {'emojis__emoji': '💨', 'count': 29},
#  {'emojis__emoji': '⏲️', 'count': 25},
#  {'emojis__emoji': '🔎', 'count': 23},
#  {'emojis__emoji': '🥰', 'count': 22},
#  {'emojis__emoji': '🏹', 'count': 21},
#  {'emojis__emoji': '🐗', 'count': 21},
#  {'emojis__emoji': '👁️', 'count': 20},
#  {'emojis__emoji': '🤘', 'count': 19},
#  {'emojis__emoji': '🤙', 'count': 19},
#  {'emojis__emoji': '😏', 'count': 18},
#  {'emojis__emoji': '⌚', 'count': 16},
#  {'emojis__emoji': '👍', 'count': 15},
#  {'emojis__emoji': '🦀', 'count': 15},
#  {'emojis__emoji': '🐙', 'count': 15},
#  {'emojis__emoji': '🖕', 'count': 14},
#  {'emojis__emoji': '⚠', 'count': 13},
#  {'emojis__emoji': '⏰', 'count': 12},
#  {'emojis__emoji': '🎻', 'count': 11},
#  {'emojis__emoji': '💀', 'count': 9},
#  {'emojis__emoji': '🪝', 'count': 9},
#  {'emojis__emoji': '❗', 'count': 9},
#  {'emojis__emoji': '🙏', 'count': 8},
#  {'emojis__emoji': '📣', 'count': 8},
#  {'emojis__emoji': '💤', 'count': 8},
#  {'emojis__emoji': '🔥', 'count': 8},
#  {'emojis__emoji': '😍', 'count': 8},
#  {'emojis__emoji': '🌿', 'count': 6},
#  {'emojis__emoji': '🎵', 'count': 6},
#  {'emojis__emoji': '⏲', 'count': 6},
#  {'emojis__emoji': '🌰', 'count': 5},
#  {'emojis__emoji': '🍅', 'count': 5},
#  {'emojis__emoji': '🐦', 'count': 4},
#  {'emojis__emoji': '🇨🇺', 'count': 4},
#  {'emojis__emoji': '⛏️', 'count': 4},
#  {'emojis__emoji': '🔔', 'count': 4},
#  {'emojis__emoji': '📈', 'count': 4},
#  {'emojis__emoji': '🕚', 'count': 4},
#  {'emojis__emoji': '🤓', 'count': 4},
#  {'emojis__emoji': '🐉', 'count': 4},
#  {'emojis__emoji': '🕑', 'count': 4},
#  {'emojis__emoji': '🌊', 'count': 3},
#  {'emojis__emoji': '🪵', 'count': 3},
#  {'emojis__emoji': '🕜', 'count': 3},
#  {'emojis__emoji': '🐷', 'count': 3},
#  {'emojis__emoji': '🐽', 'count': 3},
#  {'emojis__emoji': '🔴', 'count': 3},
#  {'emojis__emoji': '👈', 'count': 3},
#  {'emojis__emoji': '😂', 'count': 3},
#  {'emojis__emoji': '😳', 'count': 2},
#  {'emojis__emoji': '🎶', 'count': 2},
#  {'emojis__emoji': '✋', 'count': 2},
#  {'emojis__emoji': '🚬', 'count': 2},
#  {'emojis__emoji': '💡', 'count': 2},
#  {'emojis__emoji': '🍽️', 'count': 2},
#  {'emojis__emoji': '👀', 'count': 2},
#  {'emojis__emoji': '😊', 'count': 2},
#  {'emojis__emoji': '🥕', 'count': 2},
#  {'emojis__emoji': '🍆', 'count': 2},
#  {'emojis__emoji': '🇺🇸', 'count': 2},
#  {'emojis__emoji': '🌳', 'count': 2},
#  {'emojis__emoji': '🥚', 'count': 2},
#  {'emojis__emoji': '🕐', 'count': 2},
#  {'emojis__emoji': '🧠', 'count': 2},
#  {'emojis__emoji': '👋', 'count': 2},
#  {'emojis__emoji': '🌏', 'count': 2},
#  {'emojis__emoji': '🥱', 'count': 2},
#  {'emojis__emoji': '☺️', 'count': 2},
#  {'emojis__emoji': '🌱', 'count': 1},
#  {'emojis__emoji': '🕛', 'count': 1},
#  {'emojis__emoji': '☑️', 'count': 1},
#  {'emojis__emoji': '🐝', 'count': 1},
#  {'emojis__emoji': '🪨', 'count': 1},
#  {'emojis__emoji': '🔭', 'count': 1},
#  {'emojis__emoji': '🍗', 'count': 1},
#  {'emojis__emoji': '💦', 'count': 1},
#  {'emojis__emoji': '🤨', 'count': 1},
#  {'emojis__emoji': '📧', 'count': 1},
#  {'emojis__emoji': '🐲', 'count': 1},
#  {'emojis__emoji': '🍄', 'count': 1},
#  {'emojis__emoji': '🌩️', 'count': 1},
#  {'emojis__emoji': '🏴', 'count': 1},
#  {'emojis__emoji': '🪓', 'count': 1},
#  {'emojis__emoji': '☮️', 'count': 1},
#  {'emojis__emoji': '🍻', 'count': 1},
#  {'emojis__emoji': '😎', 'count': 1},
#  {'emojis__emoji': '↘', 'count': 1},
#  {'emojis__emoji': '😉', 'count': 1},
#  {'emojis__emoji': '👼', 'count': 1},
#  {'emojis__emoji': '🥶', 'count': 1},
#  {'emojis__emoji': '🧙', 'count': 1},
#  {'emojis__emoji': '🌲', 'count': 1},
#  {'emojis__emoji': '🐑', 'count': 1},
#  {'emojis__emoji': '💅', 'count': 1},
#  {'emojis__emoji': '🕘', 'count': 1},
#  {'emojis__emoji': '🌟', 'count': 1},
#  {'emojis__emoji': '🥒', 'count': 1},
#  {'emojis__emoji': '🥜', 'count': 1},
#  {'emojis__emoji': '✊', 'count': 1},
#  {'emojis__emoji': '🕕', 'count': 1},
#  {'emojis__emoji': '🤣', 'count': 1},
#  {'emojis__emoji': '🐺', 'count': 1},
#  {'emojis__emoji': '🐖', 'count': 1},
#  {'emojis__emoji': '🧟', 'count': 1},
#  {'emojis__emoji': '🩲', 'count': 1},
#  {'emojis__emoji': '👹', 'count': 1},
#  {'emojis__emoji': '❕', 'count': 1},
#  {'emojis__emoji': '🥄', 'count': 1},
#  {'emojis__emoji': '🍺', 'count': 1},
#  {'emojis__emoji': '⁉️', 'count': 1},
#  {'emojis__emoji': '🦅', 'count': 1},
#  {'emojis__emoji': '🎐', 'count': 1},
#  {'emojis__emoji': '💯', 'count': 1},
#  {'emojis__emoji': '😔', 'count': 1},
#  {'emojis__emoji': '🕰️', 'count': 1},
#  {'emojis__emoji': '🇳🇱', 'count': 1},
#  {'emojis__emoji': '🧊', 'count': 1},
#  {'emojis__emoji': '🎳', 'count': 1},
#  {'emojis__emoji': '🐐', 'count': 1},
#  {'emojis__emoji': '🐟', 'count': 1},
#  {'emojis__emoji': '✏️', 'count': 1},
#  {'emojis__emoji': '😋', 'count': 1},
#  {'emojis__emoji': '✅', 'count': 1},
#  {'emojis__emoji': '😡', 'count': 1},
#  {'emojis__emoji': '🪱', 'count': 1}]
